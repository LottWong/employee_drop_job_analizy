# %%
import pandas
pfm = pandas.read_csv("pfm_train.csv")
#pfm.describe()
pfm.sample(5)
# Out:
#      Age  Attrition BusinessTravel              Department  DistanceFromHome  \
# 657   46          0  Travel_Rarely  Research & Development                 2
# 374   46          0  Travel_Rarely  Research & Development                 8
# 427   34          0  Travel_Rarely  Research & Development                20
# 902   36          0  Travel_Rarely  Research & Development                 6
# 763   31          0  Travel_Rarely  Research & Development                11
#
#      Education    EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# 657          4           Medical            1789                        3
# 374          4     Life Sciences            1080                        4
# 427          3  Technical Degree            1265                        3
# 902          3     Life Sciences              97                        2
# 763          4     Life Sciences             895                        4
#
#      Gender  ...  RelationshipSatisfaction  StandardHours StockOptionLevel  \
# 657    Male  ...                         3             80                1
# 374  Female  ...                         1             80                3
# 427  Female  ...                         4             80                0
# 902  Female  ...                         2             80                0
# 763    Male  ...                         2             80                1
#
#      TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 657                 24                     3                3               2
# 374                 19                     2                3              16
# 427                  2                     5                2               1
# 902                  5                     3                3               1
# 763                  8                     2                3               6
#
#     YearsInCurrentRole YearsSinceLastPromotion  YearsWithCurrManager
# 657                  1                       2                     2
# 374                 13                       1                     7
# 427                  0                       0                     0
# 902                  0                       0                     0
# 763                  4                       0                     2
#
# [5 rows x 31 columns]

# %%
import seaborn
# %matplotlib inline
seaborn.regplot(x='Age',y='Attrition', data=pfm)

# %%
from sklearn import linear_model
from sklearn.model_selection import cross_val_score
import numpy as np
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit(pfm['Attrition'])
lm = linear_model.LogisticRegression(max_iter=10000)
features = ['Age',
            'DistanceFromHome',
            'Education',
            'EmployeeNumber',
            'EnvironmentSatisfaction',
            'JobInvolvement',
            'JobLevel',
            'JobSatisfaction',
            'MonthlyIncome',
            'NumCompaniesWorked',
            'PercentSalaryHike',
            'PerformanceRating',
            'RelationshipSatisfaction',
            'StandardHours',
            'StockOptionLevel',
            'TotalWorkingYears',
            'TrainingTimesLastYear',
            'WorkLifeBalance',
            'YearsAtCompany',
            'YearsInCurrentRole',
            'YearsSinceLastPromotion',
            'YearsWithCurrManager']
x = pfm[features]
y = le.transform(pfm['Attrition'])
#y = pfm['Attrition']
#print(y)
scores = cross_val_score(lm,x,y,cv=5,scoring='accuracy')
print(np.mean(scores))
model = lm.fit(x,y)
#print(model.predict(34))
#print(model.intercept_, model.coef_)
# Out:
# 0.850909090909091

# %%
reader = pandas.read_csv("pfm_test.csv")
lenth = len(reader)
p0=0
p1=0
for i in range(lenth):
    tmp = [[reader.loc[i]['Age'],
            reader.loc[i]['DistanceFromHome'],
            reader.loc[i]['Education'],
            reader.loc[i]['EmployeeNumber'],
            reader.loc[i]['EnvironmentSatisfaction'],
            reader.loc[i]['JobInvolvement'],
            reader.loc[i]['JobLevel'],
            reader.loc[i]['JobSatisfaction'],
            reader.loc[i]['MonthlyIncome'],
            reader.loc[i]['NumCompaniesWorked'],
            reader.loc[i]['PercentSalaryHike'],
            reader.loc[i]['PerformanceRating'],
            reader.loc[i]['RelationshipSatisfaction'],
            reader.loc[i]['StandardHours'],
            reader.loc[i]['StockOptionLevel'],
            reader.loc[i]['TotalWorkingYears'],
            reader.loc[i]['TrainingTimesLastYear'],
            reader.loc[i]['WorkLifeBalance'],
            reader.loc[i]['YearsAtCompany'],
            reader.loc[i]['YearsInCurrentRole'],
            reader.loc[i]['YearsSinceLastPromotion'],
            reader.loc[i]['YearsWithCurrManager']]]
    #print(tmp)
    #print(model.predict(tmp))
    result = model.predict(tmp)
    if 0 == result:
        p0+=1
    else:
        p1+=1
    reader.loc[i,'Attrition'] = result
    #print(reader.loc[i]['BusinessTravel'])
print(p0)
print(p1)
reader.to_csv("pfm_test.csv")

# %%
reader = pandas.read_csv("pfm_train.csv")
lenth = len(reader)
p1=0
p2=0
for i in range(lenth):
    tmp = [[reader.loc[i]['Age'],
            reader.loc[i]['DistanceFromHome'],
            reader.loc[i]['Education'],
            reader.loc[i]['EmployeeNumber'],
            reader.loc[i]['EnvironmentSatisfaction'],
            reader.loc[i]['JobInvolvement'],
            reader.loc[i]['JobLevel'],
            reader.loc[i]['JobSatisfaction'],
            reader.loc[i]['MonthlyIncome'],
            reader.loc[i]['NumCompaniesWorked'],
            reader.loc[i]['PercentSalaryHike'],
            reader.loc[i]['PerformanceRating'],
            reader.loc[i]['RelationshipSatisfaction'],
            reader.loc[i]['StandardHours'],
            reader.loc[i]['StockOptionLevel'],
            reader.loc[i]['TotalWorkingYears'],
            reader.loc[i]['TrainingTimesLastYear'],
            reader.loc[i]['WorkLifeBalance'],
            reader.loc[i]['YearsAtCompany'],
            reader.loc[i]['YearsInCurrentRole'],
            reader.loc[i]['YearsSinceLastPromotion'],
            reader.loc[i]['YearsWithCurrManager']]]
    result = model.predict(tmp)
    if 1 == result:
        p1+=1
    else:
        p0+=1
print(p0)
print(p1)
